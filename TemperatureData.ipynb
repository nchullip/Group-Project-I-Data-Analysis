# %%
import pandas as pd
import os

csv_path = os.path.join("C:\\Users\\mas34\\Downloads\\TemperatureDataFiltered.csv")

temperature_df = pd.read_csv(csv_path)

reduced_df = temperature_df[["dt", "AverageTemperature", "Country"]]

reduced_df['dt'] = pd.to_datetime(reduced_df['dt'])
pd.to_datetime(reduced_df['dt'])

reduced_df.dtypes

reduced_df['temp_year'] = reduced_df['dt'].dt.to_period('Y') 

#print( reduced_df['dt'].dt.to_period('Y') )

semifinal_df = reduced_df[['AverageTemperature', 'Country', 'temp_year']]

semifinal_df.groupby(['Country', "temp_year"]).mean()

reduced_df = temperature_df[["dt", "AverageTemperature", "Country"]]

reduced_df['dt'] = pd.to_datetime(reduced_df['dt'])
pd.to_datetime(reduced_df['dt'])

reduced_df.dtypes

reduced_df['temp_year'] = reduced_df['dt'].dt.to_period('Y') 

#print( reduced_df['dt'].dt.to_period('Y') )

semifinal_df = reduced_df[['AverageTemperature', 'Country', 'temp_year']]

semifinal_df.groupby(['Country', "temp_year"]).mean()
# Out:
# C:\Users\mas34\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\mas34\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          AverageTemperature
# Country       temp_year
# Brazil        1950                24.639000
#               1951                24.797333
#               1952                24.851667
# ...
