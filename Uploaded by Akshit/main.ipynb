# %%
# Importing Dependencies
import pandas as pd
import numpy as np
from CreateDictOfDataFrames import create_dataFrame
from GetCountryList import get_country_list
from TemperatureData import averagetemperature_df
import matplotlib.pyplot as plt

# %%
# Loading the Datafiles
population_data_file = "Resources\world_population_2018aug.csv"
temp_df = "Resources/GlobalLandTemperaturesByCountry.csv"
world_data_df = pd.read_csv('Resources\WDIData.csv')

# %%
# Get top five countries with the most population as a Python List
country_list = get_country_list(data_file = population_data_file, num = 5)
country_list
# Out:
# ['China', 'India', 'United States', 'Indonesia', 'Pakistan']

# %%
# Compute and create Pandas DataFrames for CO2 Emissions, Forest Area Percentage and Air Quality Index for the countries
dict_Of_dataFrames = create_dataFrame(country_list = country_list, full_data_df = world_data_df)

# %%
dict_Of_dataFrames["China"][2].head()
# Out:
#   Years Air Pollution Index
# 0  1990              57.765
# 1  1995             58.6602
# 2  2000             60.7048
# 3  2005             66.1745
# 4  2010             69.4796

# %%
# CO2 EMISSION, FOREST AREA PERCENTAGE and AIR QUALITY INDEX for top 5 countries

# China information
china_co2_df = dict_Of_dataFrames['China'][0]
china_forest_df = dict_Of_dataFrames['China'][1]
china_airpollution_df = dict_Of_dataFrames['China'][2]
# size for CO2 emission
china_co2_size = np.power(china_co2_df["CO2 Emissions"].tolist(),3)
# size for Forest Area Percentage
china_fap_size = np.power(china_forest_df["Forest Area Percentage"].tolist(),2)
# size for Air Quality Index
china_aqi_size = np.power(china_airpollution_df["Air Pollution Index"].tolist(),2)

# India information
india_co2_df = dict_Of_dataFrames['India'][0]
india_forest_df = dict_Of_dataFrames['India'][1]
india_airpollution_df = dict_Of_dataFrames['India'][2]
# size for Co2 emission
india_co2_size = np.power(india_co2_df["CO2 Emissions"].tolist(),3)
# size for Forest Area Percentage
india_fap_size = np.power(india_forest_df["Forest Area Percentage"].tolist(),2)
# size for Air Quality Index
india_aqi_size = np.power(india_airpollution_df["Air Pollution Index"].tolist(),2)


# United States information
us_co2_df = dict_Of_dataFrames['United States'][0]
us_forest_df = dict_Of_dataFrames['United States'][1]
us_airpollution_df = dict_Of_dataFrames['United States'][2]
# size for CO2 emission
us_co2_size = np.power(us_co2_df["CO2 Emissions"].tolist(),3)
# size for Forest Area Percentage
us_fap_size = np.power(us_forest_df["Forest Area Percentage"].tolist(),2)
# size for Air Quality Index
us_aqi_size = np.power(us_airpollution_df["Air Pollution Index"].tolist(),2)


# Indonesia information
indonesia_co2_df = dict_Of_dataFrames['Indonesia'][0]
indonesia_forest_df = dict_Of_dataFrames['Indonesia'][1]
indonesia_airpollution_df = dict_Of_dataFrames['Indonesia'][2]
# size for CO2 emission
indonesia_co2_size = np.power(indonesia_co2_df["CO2 Emissions"].tolist(),6)
# size for Forest Area Percentage
indonesia_fap_size = np.power(indonesia_forest_df["Forest Area Percentage"].tolist(),2)
# size for Air Quality Index
indonesia_aqi_size = np.power(indonesia_airpollution_df["Air Pollution Index"].tolist(),2)

# Pakistan information
pakistan_co2_df = dict_Of_dataFrames['Pakistan'][0]
pakistan_forest_df = dict_Of_dataFrames['Pakistan'][1]
pakistan_airpollution_df = dict_Of_dataFrames['Pakistan'][2]
# size for CO2 emission
pakistan_co2_size = np.power(pakistan_co2_df["CO2 Emissions"].tolist(),6)
# size for Forest Area Percentage
pakistan_fap_size = np.power(pakistan_forest_df["Forest Area Percentage"].tolist(),2)
# size for Air Quality Index
pakistan_aqi_size = np.power(pakistan_airpollution_df["Air Pollution Index"].tolist(),2)

# %%
china_airpollution_df.head()
# Out:
#   Years Air Pollution Index
# 0  1990              57.765
# 1  1995             58.6602
# 2  2000             60.7048
# 3  2005             66.1745
# 4  2010             69.4796

# %% [markdown]
# ## Scatter Plot

# %%
# CO2 Emission scatter plot

fig = plt.figure(figsize=(15,8))
plt.grid(True)

# setting x and y limits
#plt.xlim(1960,2014)
plt.ylim(0,30)

# Countries information
china_co2_sctr = plt.scatter(china_co2_df["Years"], china_co2_df["CO2 Emissions"], china_co2_size, marker="o",label="China", color="green")
india_co2_sctr = plt.scatter(india_co2_df["Years"], india_co2_df["CO2 Emissions"], india_co2_size, marker="o",label="India", color="yellow")
us_co2_sctr = plt.scatter(us_co2_df["Years"], us_co2_df["CO2 Emissions"], us_co2_size, marker="o", label="United States", color="blue")
indonesia_co2_sctr = plt.scatter(indonesia_co2_df["Years"], indonesia_co2_df["CO2 Emissions"], indonesia_co2_size, marker="o",label="Indonesia", color="red")
pakistan_co2_sctr = plt.scatter(pakistan_co2_df["Years"], pakistan_co2_df["CO2 Emissions"], pakistan_co2_size, marker="o", label="Pakistan", color="gray")

# Ticks for the year = vertical
plt.xticks(rotation="vertical")

# axis labels and title
plt.title("CO2 Country Comparisson")
plt.xlabel("Year")
plt.ylabel("CO2 Emissions (metric tons per capita)")
plt.savefig("CO2_bubblegraph.png")

# Legend properties
graph_legend = plt.legend(handles=[china_co2_sctr, india_co2_sctr, us_co2_sctr, indonesia_co2_sctr, pakistan_co2_sctr],loc="best")
graph_legend.legendHandles[0]._sizes = [70]
graph_legend.legendHandles[1]._sizes = [70]
graph_legend.legendHandles[2]._sizes = [70]
graph_legend.legendHandles[3]._sizes = [70]
graph_legend.legendHandles[4]._sizes = [70]

# %%
# Forest Area Percentage scatter plot
# NOTE: The forest size in the figure is dependent on the country's land size. Such as China is bigger than Indonesia

fig = plt.figure(figsize=(15,8))
plt.grid(True)

# setting x and y limits
#plt.xlim(1960,2014)
plt.ylim(0,80)

# Countries information
china_forest_sctr = plt.scatter(china_forest_df["Years"], china_forest_df["Forest Area Percentage"], china_fap_size, marker="o",label="China", color="green")
india_forest_sctr = plt.scatter(india_forest_df["Years"], india_forest_df["Forest Area Percentage"], india_fap_size, marker="o",label="India", color="yellow")
us_forest_sctr = plt.scatter(us_forest_df["Years"], us_forest_df["Forest Area Percentage"], us_fap_size, marker="o", label="United States", color="blue")
indonesia_forest_sctr = plt.scatter(indonesia_forest_df["Years"], indonesia_forest_df["Forest Area Percentage"], indonesia_fap_size, marker="o",label="Indonesia", color="red")
pakistan_forest_sctr = plt.scatter(pakistan_forest_df["Years"], pakistan_forest_df["Forest Area Percentage"], pakistan_fap_size, marker="o", label="Pakistan", color="gray")

# Ticks for the year = vertical
plt.xticks(rotation="vertical")

# axis labels and title
plt.title("Forest Area Percentage country comparisson")
plt.xlabel("Year")
plt.ylabel("Forest Area Percentage")
plt.savefig("Forestarea_bubblegraph.png")

# Legend properties
graph_legend = plt.legend(handles=[china_forest_sctr, india_forest_sctr, us_forest_sctr, indonesia_forest_sctr, pakistan_forest_sctr],loc="best")
graph_legend.legendHandles[0]._sizes = [70]
graph_legend.legendHandles[1]._sizes = [70]
graph_legend.legendHandles[2]._sizes = [70]
graph_legend.legendHandles[3]._sizes = [70]
graph_legend.legendHandles[4]._sizes = [70]

# %%
# Air Quality Index scatter plot

fig = plt.figure(figsize=(15,8))
plt.grid(True)

# setting x and y limits
#plt.xlim(1960,2014)
plt.ylim(5,120)

# Countries information
china_airpollution_sctr = plt.scatter(china_airpollution_df["Years"], china_airpollution_df["Air Pollution Index"], china_aqi_size, marker="o",label="China", color="green")
india_airpollution_sctr = plt.scatter(india_airpollution_df["Years"], india_airpollution_df["Air Pollution Index"], india_aqi_size, marker="o",label="India", color="yellow")
us_airpollution_sctr = plt.scatter(us_airpollution_df["Years"], us_airpollution_df["Air Pollution Index"], us_aqi_size, marker="o", label="United States", color="blue")
indonesia_airpollution_sctr = plt.scatter(indonesia_airpollution_df["Years"], indonesia_airpollution_df["Air Pollution Index"], indonesia_aqi_size, marker="o",label="Indonesia", color="red")
pakistan_airpollution_sctr = plt.scatter(pakistan_airpollution_df["Years"], pakistan_airpollution_df["Air Pollution Index"], pakistan_aqi_size, marker="o", label="Pakistan", color="gray")

# Ticks for the year = vertical
plt.xticks(rotation="vertical")

# axis labels and title
plt.title("Air Quality Index country comparisson")
plt.xlabel("Year")
plt.ylabel("Air Quality Index (micrograms per cubic meter)")
plt.savefig("Airquality_bubblegraph.png")

# Legend properties
graph_legend = plt.legend(handles=[china_airpollution_sctr, india_airpollution_sctr, us_airpollution_sctr, indonesia_airpollution_sctr, pakistan_airpollution_sctr],loc="best")
graph_legend.legendHandles[0]._sizes = [70]
graph_legend.legendHandles[1]._sizes = [70]
graph_legend.legendHandles[2]._sizes = [70]
graph_legend.legendHandles[3]._sizes = [70]
graph_legend.legendHandles[4]._sizes = [70]

# %% [markdown]
# ## Average Comparisson of CO2, Forest Area and Air Quality Index (Bar Chart)

# %%
# CO2 emissions
china_co2_ave = china_co2_df.loc[:,"CO2 Emissions"].mean()
india_co2_ave = india_co2_df.loc[:,"CO2 Emissions"].mean()
us_co2_ave = us_co2_df.loc[:,"CO2 Emissions"].mean()
indonesia_co2_ave = indonesia_co2_df.loc[:,"CO2 Emissions"].mean()
pakistan_co2_ave = pakistan_co2_df.loc[:,"CO2 Emissions"].mean()

# %%
# Data frame info
co2_dict = {'Country': ['China', 'India','USA','Indonesia','Pakistan'], 'CO2 Average': [china_co2_ave, india_co2_ave, us_co2_ave, indonesia_co2_ave, pakistan_co2_ave]}
co2_ave_df=pd.DataFrame(co2_dict)
co2_ave_df.head()
# Out:
#      Country  CO2 Average
# 0      China     2.487313
# 1      India     0.703525
# 2        USA    19.183689
# 3  Indonesia     0.912486
# 4   Pakistan     0.574835

# %%
# Axis and bar chart
x_axis = co2_ave_df["Country"]
y_axis = co2_ave_df["CO2 Average"]

# Average CO2 per country
plt.bar(x_axis, y_axis, color='red', alpha=0.7, align="center")

# Chart title and labels
plt.title("Average CO2 for top 5 populated Countries")
plt.xlabel("Countries")
plt.ylabel("Average CO2 Emission (metric tons per capita)")
plt.show()
plt.savefig("CO2_bargraph.png")

# %%
# Forest Area Percentage
china_forest_ave = china_forest_df.loc[:,"Forest Area Percentage"].mean()
india_forest_ave = india_forest_df.loc[:,"Forest Area Percentage"].mean()
us_forest_ave = us_forest_df.loc[:,"Forest Area Percentage"].mean()
indonesia_forest_ave = indonesia_forest_df.loc[:,"Forest Area Percentage"].mean()
pakistan_forest_ave = pakistan_forest_df.loc[:,"Forest Area Percentage"].mean()

# %%
# Data frame info
forest_dict = {'Country': ['China', 'India','USA','Indonesia','Pakistan'], 'Forest Area Percentage': [china_forest_ave, india_forest_ave, us_forest_ave, indonesia_forest_ave, pakistan_forest_ave]}
forest_ave_df=pd.DataFrame(forest_dict)
forest_ave_df.head()
# Out:
#      Country  Forest Area Percentage
# 0      China               19.394474
# 1      India               22.428840
# 2        USA               33.297533
# 3  Indonesia               56.335471
# 4   Pakistan                2.656191

# %%
# Axis and bart
# NOTE : as the forest area is proportionate to land area, obviously Indonesia has a higer percentage of forest area than China
x_axis = forest_ave_df["Country"]
y_axis = forest_ave_df["Forest Area Percentage"]

# Average CO2 per country
plt.bar(x_axis, y_axis, color='green', alpha=0.7, align="center")

# Chart title and labels
plt.title("Average Forest Area of top 5 populated Countries")
plt.xlabel("Countries")
plt.ylabel("Forest Area Percentage")
plt.show()
plt.savefig("forest_bargraph.png")

# %%
# Air quality index
china_airpollution_ave = china_airpollution_df.loc[:,"Air Pollution Index"].mean()
india_airpollution_ave = india_airpollution_df.loc[:,"Air Pollution Index"].mean()
us_airpollution_ave = us_airpollution_df.loc[:,"Air Pollution Index"].mean()
indonesia_airpollution_ave = indonesia_airpollution_df.loc[:,"Air Pollution Index"].mean()
pakistan_airpollution_ave = pakistan_airpollution_df.loc[:,"Air Pollution Index"].mean()

# %%
# Data frame info
airpollution_dict = {'Country': ['China', 'India','USA','Indonesia','Pakistan'], 'Air Pollution Index': [china_airpollution_ave, india_airpollution_ave, us_airpollution_ave, indonesia_airpollution_ave, pakistan_airpollution_ave]}
airpollution_ave_df=pd.DataFrame(airpollution_dict)
airpollution_ave_df.head()
# Out:
#      Country  Air Pollution Index
# 0      China            64.083459
# 1      India            88.985623
# 2        USA             9.405030
# 3  Indonesia            18.036236
# 4   Pakistan            63.275116

# %%
# Axis and bart
x_axis = airpollution_ave_df["Country"]
y_axis = airpollution_ave_df["Air Pollution Index"]

# Average CO2 per country
plt.bar(x_axis, y_axis, color='orange', alpha=1, align="center")

# Chart title and labels
plt.title("Average Air Pollution Index of top 5 populated Countries")
plt.xlabel("Countries")
plt.ylabel("Air Pollution Index")
plt.show()
plt.savefig("airpollution_bargraph.png")

# %%
airpollution_df_India = dict_Of_dataFrames['India'][2]
airpollution_df_China = dict_Of_dataFrames['China'][2]
airpollution_df_US = dict_Of_dataFrames['United States'][2]
airpollution_df_Indonesia = dict_Of_dataFrames['Indonesia'][2]
airpollution_df_Pakistan = dict_Of_dataFrames['Pakistan'][2]

# %%
airpollution_df_Pakistan.head()
# Out:
#   Years Air Pollution Index
# 0  1990             60.3347
# 1  1995             61.4329
# 2  2000              61.106
# 3  2005             63.3784
# 4  2010             68.0052

# %%
x_axis = np.arange(0, 130)
fig = plt.figure(figsize=(15,6))
plt.ylim(0, 130)
china, = plt.plot (airpollution_df_China["Years"], airpollution_df_China["Air Pollution Index"], marker = "+", color = "r", linewidth = 1, label = "China")
india, = plt.plot (airpollution_df_India["Years"], airpollution_df_India["Air Pollution Index"], marker = "^", color = "b", linewidth = 1, label = "India")
us, = plt.plot (airpollution_df_US["Years"], airpollution_df_US["Air Pollution Index"], marker = ">", color = "g", linewidth = 1, label = "U.S.")
indonesia, = plt.plot (airpollution_df_Indonesia["Years"], airpollution_df_Indonesia["Air Pollution Index"], marker = "<", color = "m", linewidth = 1, label = "Indonesia")
pakistan, = plt.plot(airpollution_df_Pakistan["Years"], airpollution_df_Pakistan["Air Pollution Index"], marker = "o", color = "y", linewidth = 1, label = "Pakistan")

plt.title("Air Pollution(pm2.5) over Time")
plt.xlabel("Years")
plt.ylabel("Air pollution Index")
plt.legend(handles=[us, china, india, indonesia, pakistan])
plt.grid()
plt.show()
plt.savefig("Airpollution_scatter.png")

# %%
co2_df_India = dict_Of_dataFrames['India'][0]
co2_df_China = dict_Of_dataFrames['China'][0]
co2_df_US = dict_Of_dataFrames['United States'][0]
co2_df_Indonesia = dict_Of_dataFrames['Indonesia'][0]
co2_df_Pakistan = dict_Of_dataFrames['Pakistan'][0]
co2_df_US.head()
# Out:
#   Years CO2 Emissions
# 4  1960       15.9998
# 5  1961       15.6813
# 6  1962       16.0139
# 7  1963       16.4828
# 8  1964       16.9681

# %%
fig = plt.figure(figsize=(15,6))
x_axis = np.arange(1990, 2017)
plt.ylim(0, 25)
china, = plt.plot (co2_df_China["Years"], co2_df_China["CO2 Emissions"], marker = "+", color = "r", linewidth = 1, label = "China")
india, = plt.plot (co2_df_India["Years"], co2_df_India["CO2 Emissions"], marker = "^", color = "b", linewidth = 1, label = "India")
us, = plt.plot (co2_df_US["Years"], co2_df_US["CO2 Emissions"], marker = ">", color = "g", linewidth = 1, label = "U.S.")
indonesia, = plt.plot (co2_df_Indonesia["Years"], co2_df_Indonesia["CO2 Emissions"], marker = "<", color = "m", linewidth = 1, label = "Indonesia")
pakistan, = plt.plot(co2_df_Pakistan["Years"], co2_df_Pakistan["CO2 Emissions"], marker = "o", color = "y", linewidth = 1, label = "Pakistan")

plt.title("Average CO2 Emissions Over Time")
plt.xlabel("Years")
plt.ylabel("Metric Tonnes of CO2 per capita")
plt.xticks(rotation="vertical")
plt.legend(handles=[us, china, india, indonesia, pakistan])
plt.grid()
plt.show()
plt.savefig("CO2_scatter.png")

# %%
forest_df_India = dict_Of_dataFrames['India'][1]
forest_df_China = dict_Of_dataFrames['China'][1]
forest_df_US = dict_Of_dataFrames['United States'][1]
forest_df_Indonesia = dict_Of_dataFrames['Indonesia'][1]
forest_df_Pakistan = dict_Of_dataFrames['Pakistan'][1]
forest_df_Indonesia.head()
# Out:
#   Years Forest Area Percentage
# 4  1990                65.4377
# 5  1991                64.3814
# 6  1992                63.3251
# 7  1993                62.2688
# 8  1994                61.2124

# %%
fig = plt.figure(figsize=(15,6))
x_axis = np.arange(1990, 2017)
plt.ylim(0, 70)
china, = plt.plot (forest_df_China["Years"], forest_df_China["Forest Area Percentage"], marker = "+", color = "r", linewidth = 1, label = "China")
india, = plt.plot (forest_df_India["Years"], forest_df_India["Forest Area Percentage"], marker = "^", color = "b", linewidth = 1, label = "India")
us, = plt.plot (forest_df_US["Years"], forest_df_US["Forest Area Percentage"], marker = ">", color = "g", linewidth = 1, label = "U.S.")
indonesia, = plt.plot (forest_df_Indonesia["Years"], forest_df_Indonesia["Forest Area Percentage"], marker = "<", color = "m", linewidth = 1, label = "Indonesia")
pakistan, = plt.plot(forest_df_Pakistan["Years"], forest_df_Pakistan["Forest Area Percentage"], marker = "o", color = "y", linewidth = 1, label = "Pakistan")

plt.title("Forest Area Percentage over Time")
plt.xlabel("Years")
plt.ylabel("Percentage of Forest Area")
plt.xticks(rotation="vertical")
plt.legend(handles=[us, china, india, indonesia, pakistan])
plt.grid()
plt.show()
plt.savefig("forest_scatter.png")
